# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/MyDrive/IronHack/Data Analysis/Bootcamp/Proyecto Final/Datasets Base/Banking_Crisis_Dummies.csv')
df2 = pd.read_csv('/content/drive/MyDrive/IronHack/Data Analysis/Bootcamp/Proyecto Final/Datasets Base/Macroeconomic_Indicators.csv')

# %%
df1.head()
# Out:
#                                        Series Name  ... 2017 [YR2017]
# 0  Banking crisis dummy (1=banking crisis, 0=none)  ...           0.0
# 1  Banking crisis dummy (1=banking crisis, 0=none)  ...           0.0
# 2  Banking crisis dummy (1=banking crisis, 0=none)  ...           0.0
# 3  Banking crisis dummy (1=banking crisis, 0=none)  ...           0.0
# 4  Banking crisis dummy (1=banking crisis, 0=none)  ...           0.0
#
# [5 rows x 16 columns]

# %%
df2.head()
# Out:
#   Country Name Country Code  ...     2019 [YR2019]     2020 [YR2020]
# 0    Argentina          ARG  ...  15.7963628519449  17.8537791737235
# 1    Argentina          ARG  ...  422995834686.456  358374943437.124
# 2    Argentina          ARG  ...  445445177459.453   383066977653.56
# 3    Argentina          ARG  ...  9912.28180859863   8441.9194391094
# 4    Argentina          ARG  ...        2983330000        2183040000
#
# [5 rows x 35 columns]

# %%
df2[df2['Country Name'] == 'Afghanistan']
# Out:
#     Country Name Country Code  ...      2019 [YR2019]      2020 [YR2020]
# 520  Afghanistan          AFG  ...                 ..                 ..
# 521  Afghanistan          AFG  ...                 ..                 ..
# 522  Afghanistan          AFG  ...   19291104007.6135   19807067268.1084
# 523  Afghanistan          AFG  ...   507.103391875763   508.808409485223
# 524  Afghanistan          AFG  ...                 ..                 ..
# 525  Afghanistan          AFG  ...   490.232314247094                 ..
# 526  Afghanistan          AFG  ...                 ..                 ..
# 527  Afghanistan          AFG  ...  -3791935256.04003  -3136120114.98308
# 528  Afghanistan          AFG  ...                 ..                 ..
# 529  Afghanistan          AFG  ...                 ..                 ..
# 530  Afghanistan          AFG  ...   26321046.5766518   37228478.0954418
# 531  Afghanistan          AFG  ...                 ..                 ..
# ...

# %%
col_names = df2['Series Name'].unique()
col_names.tolist()
# Out:
# ['Gross savings (% of GDP)',
#  'Gross national expenditure (current US$)',
#  'GDP (current US$)',
#  'GDP per capita (current US$)',
#  'Stocks traded, total value (current US$)',
#  'Adjusted net national income per capita (current US$)',
#  'Changes in inventories (current US$)',
#  'Current account balance (BoP, current US$)',
#  'Exports of goods and services (current US$)',
#  'External balance on goods and services (current US$)',
#  'Foreign direct investment, net outflows (BoP, current US$)',
#  'Imports of goods and services (current US$)',
#  'Industry (including construction), value added (current US$)',
#  'International tourism, receipts (current US$)',
#  'Market capitalization of listed domestic companies (current US$)',
#  'Personal remittances, received (current US$)',
#  'Personal remittances, paid (current US$)',
#  'Portfolio equity, net inflows (BoP, current US$)',
#  'Portfolio investment, bonds (PPG + PNG) (NFL, current US$)',
# ...

# %%
len(col_names)
# Out:
# 27

# %%
data = df2.merge(df1, on='Country Name')
data.head()
# Out:
#   Country Name Country Code_x  ... 2016 [YR2016]_y 2017 [YR2017]_y
# 0    Argentina            ARG  ...             0.0             0.0
# 1    Argentina            ARG  ...             0.0             0.0
# 2    Argentina            ARG  ...             0.0             0.0
# 3    Argentina            ARG  ...             0.0             0.0
# 4    Argentina            ARG  ...             0.0             0.0
#
# [5 rows x 50 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5475 entries, 0 to 5474
# Data columns (total 50 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country Name     5460 non-null   object
#  1   Country Code_x   5460 non-null   object
#  2   Series Name_x    5460 non-null   object
#  3   Series Code_x    5460 non-null   object
#  4   1990 [YR1990]_x  5460 non-null   object
#  5   1991 [YR1991]    5460 non-null   object
#  6   1992 [YR1992]    5460 non-null   object
#  7   1993 [YR1993]    5460 non-null   object
#  8   1994 [YR1994]    5460 non-null   object
#  9   1995 [YR1995]    5460 non-null   object
#  10  1996 [YR1996]    5460 non-null   object
#  11  1997 [YR1997]    5460 non-null   object
#  12  1998 [YR1998]    5460 non-null   object
#  13  1999 [YR1999]    5460 non-null   object
#  14  2000 [YR2000]_x  5460 non-null   object
#  15  2001 [YR2001]    5460 non-null   object
# ...

# %%
data.drop(['Series Name_y','Series Code_y','Country Code_y'], inplace=True, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5475 entries, 0 to 5474
# Data columns (total 47 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country Name     5460 non-null   object
#  1   Country Code_x   5460 non-null   object
#  2   Series Name_x    5460 non-null   object
#  3   Series Code_x    5460 non-null   object
#  4   1990 [YR1990]_x  5460 non-null   object
#  5   1991 [YR1991]    5460 non-null   object
#  6   1992 [YR1992]    5460 non-null   object
#  7   1993 [YR1993]    5460 non-null   object
#  8   1994 [YR1994]    5460 non-null   object
#  9   1995 [YR1995]    5460 non-null   object
#  10  1996 [YR1996]    5460 non-null   object
#  11  1997 [YR1997]    5460 non-null   object
#  12  1998 [YR1998]    5460 non-null   object
#  13  1999 [YR1999]    5460 non-null   object
#  14  2000 [YR2000]_x  5460 non-null   object
#  15  2001 [YR2001]    5460 non-null   object
# ...

# %%
data.head()
# Out:
#   Country Name Country Code_x  ... 2016 [YR2016]_y 2017 [YR2017]_y
# 0    Argentina            ARG  ...             0.0             0.0
# 1    Argentina            ARG  ...             0.0             0.0
# 2    Argentina            ARG  ...             0.0             0.0
# 3    Argentina            ARG  ...             0.0             0.0
# 4    Argentina            ARG  ...             0.0             0.0
#
# [5 rows x 47 columns]

# %%
data.isnull()
# Out:
#       Country Name  Country Code_x  ...  2016 [YR2016]_y  2017 [YR2017]_y
# 0            False           False  ...            False            False
# 1            False           False  ...            False            False
# 2            False           False  ...            False            False
# 3            False           False  ...            False            False
# 4            False           False  ...            False            False
# ...            ...             ...  ...              ...              ...
# 5470          True            True  ...             True             True
# 5471          True            True  ...             True             True
# 5472          True            True  ...             True             True
# 5473          True            True  ...             True             True
# 5474          True            True  ...             True             True
#
# [5475 rows x 47 columns]

# %%
data.isnull().sum()
# Out:
# Country Name       15
# Country Code_x     15
# Series Name_x      15
# Series Code_x      15
# 1990 [YR1990]_x    15
# 1991 [YR1991]      15
# 1992 [YR1992]      15
# 1993 [YR1993]      15
# 1994 [YR1994]      15
# 1995 [YR1995]      15
# 1996 [YR1996]      15
# 1997 [YR1997]      15
# 1998 [YR1998]      15
# 1999 [YR1999]      15
# 2000 [YR2000]_x    15
# 2001 [YR2001]      15
# 2002 [YR2002]      15
# 2003 [YR2003]      15
# 2004 [YR2004]      15
# 2005 [YR2005]      15
# 2006 [YR2006]      15
# 2007 [YR2007]      15
# 2008 [YR2008]_x    15
# 2009 [YR2009]_x    15
# 2010 [YR2010]_x    15
# 2011 [YR2011]_x    15
# 2012 [YR2012]_x    15
# 2013 [YR2013]_x    15
# 2014 [YR2014]_x    15
# 2015 [YR2015]_x    15
# 2016 [YR2016]_x    15
# 2017 [YR2017]_x    15
# 2018 [YR2018]      15
# 2019 [YR2019]      15
# 2020 [YR2020]      15
# 1990 [YR1990]_y    15
# 2000 [YR2000]_y    15
# 2008 [YR2008]_y    15
# 2009 [YR2009]_y    15
# 2010 [YR2010]_y    15
# 2011 [YR2011]_y    15
# ...

# %%
data.dropna(axis=0, inplace=True)

# %%
data.isnull().sum()
# Out:
# Country Name       0
# Country Code_x     0
# Series Name_x      0
# Series Code_x      0
# 1990 [YR1990]_x    0
# 1991 [YR1991]      0
# 1992 [YR1992]      0
# 1993 [YR1993]      0
# 1994 [YR1994]      0
# 1995 [YR1995]      0
# 1996 [YR1996]      0
# 1997 [YR1997]      0
# 1998 [YR1998]      0
# 1999 [YR1999]      0
# 2000 [YR2000]_x    0
# 2001 [YR2001]      0
# 2002 [YR2002]      0
# 2003 [YR2003]      0
# 2004 [YR2004]      0
# 2005 [YR2005]      0
# 2006 [YR2006]      0
# 2007 [YR2007]      0
# 2008 [YR2008]_x    0
# 2009 [YR2009]_x    0
# 2010 [YR2010]_x    0
# 2011 [YR2011]_x    0
# 2012 [YR2012]_x    0
# 2013 [YR2013]_x    0
# 2014 [YR2014]_x    0
# 2015 [YR2015]_x    0
# 2016 [YR2016]_x    0
# 2017 [YR2017]_x    0
# 2018 [YR2018]      0
# 2019 [YR2019]      0
# 2020 [YR2020]      0
# 1990 [YR1990]_y    0
# 2000 [YR2000]_y    0
# 2008 [YR2008]_y    0
# 2009 [YR2009]_y    0
# 2010 [YR2010]_y    0
# 2011 [YR2011]_y    0
# 2012 [YR2012]_y    0
# 2013 [YR2013]_y    0
# ...

# %%
data['Series Code_x']
# Out:
# 0       NY.GNS.ICTR.ZS
# 1       NE.DAB.TOTL.CD
# 2       NY.GDP.MKTP.CD
# 3       NY.GDP.PCAP.CD
# 4       CM.MKT.TRAD.CD
#              ...
# 5455    BX.GSR.NFSV.CD
# 5456    BM.GSR.NFSV.CD
# 5457    FI.RES.TOTL.CD
# 5458    FI.RES.XGLD.CD
# 5459    DT.DOD.DIMF.CD
# Name: Series Code_x, Length: 5460, dtype: object

# %%
data.drop(['Series Code_x'],axis=1, inplace=True)

# %%
data.columns = data.columns.str.replace(r"\D+","")
data.head()
# Out:
#                    ... 20162016 20172017
# 0  Argentina  ARG  ...      0.0      0.0
# 1  Argentina  ARG  ...      0.0      0.0
# 2  Argentina  ARG  ...      0.0      0.0
# 3  Argentina  ARG  ...      0.0      0.0
# 4  Argentina  ARG  ...      0.0      0.0
#
# [5 rows x 46 columns]

# %%
data.columns = ['Country name','Country code','Indicator','1990',"1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006",
                         "2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","1990 target","2000 target","2008 target","2009 target","2010 target","2011 target","2012 target",
                "2013 target","2014 target","2015 target","2016 target","2017 target"]

# %%
data.head()
# Out:
#   Country name Country code  ... 2016 target 2017 target
# 0    Argentina          ARG  ...         0.0         0.0
# 1    Argentina          ARG  ...         0.0         0.0
# 2    Argentina          ARG  ...         0.0         0.0
# 3    Argentina          ARG  ...         0.0         0.0
# 4    Argentina          ARG  ...         0.0         0.0
#
# [5 rows x 46 columns]

# %%
data.drop(['Country code'],axis=1, inplace=True)

# %%
# data = data.transpose()
# data = data.set_index(['Country name','Country code']).T

data.head()
# Out:
#   Country name  ... 2017 target
# 0    Argentina  ...         0.0
# 1    Argentina  ...         0.0
# 2    Argentina  ...         0.0
# 3    Argentina  ...         0.0
# 4    Argentina  ...         0.0
#
# [5 rows x 45 columns]

# %%
df = data.set_index('Country name')
df.transpose()
# Out:
# Country name                 Argentina  ...                              Zimbabwe
# Indicator     Gross savings (% of GDP)  ...  Use of IMF credit (DOD, current US$)
# 1990                  16.0433766574382  ...                               6891365
# 1991                  13.5618560304189  ...                                     0
# 1992                  13.6516281676646  ...                             216150000
# 1993                  16.2505279122602  ...                           281579790.1
# 1994                  15.6483624533872  ...                           375911363.1
# 1995                  16.5116322700598  ...                           460811903.5
# 1996                  17.1300773563084  ...                           437236192.1
# 1997                  16.6642824266429  ...                           385255388.6
# 1998                  16.1297343275958  ...                           407171308.9
# ...

# %%
data.head()
# Out:
#   Country name  ... 2017 target
# 0    Argentina  ...         0.0
# 1    Argentina  ...         0.0
# 2    Argentina  ...         0.0
# 3    Argentina  ...         0.0
# 4    Argentina  ...         0.0
#
# [5 rows x 45 columns]

# %%
data = data.set_index('Indicator').T

# %%
data
# Out:
# Indicator    Gross savings (% of GDP)  ... Use of IMF credit (DOD, current US$)
# Country name                Argentina  ...                             Zimbabwe
# 1990                 16.0433766574382  ...                              6891365
# 1991                 13.5618560304189  ...                                    0
# 1992                 13.6516281676646  ...                            216150000
# 1993                 16.2505279122602  ...                          281579790.1
# 1994                 15.6483624533872  ...                          375911363.1
# 1995                 16.5116322700598  ...                          460811903.5
# 1996                 17.1300773563084  ...                          437236192.1
# 1997                 16.6642824266429  ...                          385255388.6
# 1998                 16.1297343275958  ...                          407171308.9
# 1999                 13.6619163753345  ...                          382930278.3
# ...

# %%
data.head()
# Out:
# Indicator    Gross savings (% of GDP)  ... Use of IMF credit (DOD, current US$)
# Country name                Argentina  ...                             Zimbabwe
# 1990                 16.0433766574382  ...                              6891365
# 1991                 13.5618560304189  ...                                    0
# 1992                 13.6516281676646  ...                            216150000
# 1993                 16.2505279122602  ...                          281579790.1
#
# [5 rows x 5460 columns]

# %%
df = data.transpose().reset_index()
countries = df['Country name']

# %%
dummies = df[['Country name',"1990 target","2000 target","2008 target","2009 target","2010 target","2011 target","2012 target",
                "2013 target","2014 target","2015 target","2016 target","2017 target"]]

# %%
dummies
# Out:
#      Country name 1990 target 2000 target  ... 2015 target 2016 target 2017 target
# 0       Argentina           1           0  ...           0           0           0
# 1       Argentina           1           0  ...           0           0           0
# 2       Argentina           1           0  ...           0           0           0
# 3       Argentina           1           0  ...           0           0           0
# 4       Argentina           1           0  ...           0           0           0
# ...           ...         ...         ...  ...         ...         ...         ...
# 5455     Zimbabwe           0           0  ...           0           0           0
# 5456     Zimbabwe           0           0  ...           0           0           0
# 5457     Zimbabwe           0           0  ...           0           0           0
# 5458     Zimbabwe           0           0  ...           0           0           0
# ...

# %%
data = data.iloc[0:]
data.head()
# Out:
# Indicator    Gross savings (% of GDP)  ... Use of IMF credit (DOD, current US$)
# Country name                Argentina  ...                             Zimbabwe
# 1990                 16.0433766574382  ...                              6891365
# 1991                 13.5618560304189  ...                                    0
# 1992                 13.6516281676646  ...                            216150000
# 1993                 16.2505279122602  ...                          281579790.1
#
# [5 rows x 5460 columns]

# %%
years = data.iloc[:-12]
years.columns = range(years.shape[1])
years
# Out:
#                           0                 1     ...              5458         5459
# Country name         Argentina         Argentina  ...          Zimbabwe     Zimbabwe
# 1990          16.0433766574382  133255399128.802  ...  149202984.592622      6891365
# 1991          13.5618560304189   186690084740.43  ...  149684564.648329            0
# 1992          13.6516281676646  232299611952.352  ...  222181251.804694    216150000
# 1993          16.2505279122602  242434054654.655  ...  432043634.668391  281579790.1
# 1994          15.6483624533872      265354819300  ...    405275753.9748  375911363.1
# 1995          16.5116322700598      259091370000  ...  595516728.603537  460811903.5
# 1996          17.1300773563084      273916757800  ...  598812382.519067  437236192.1
# 1997          16.6642824266429      299344177400  ...  160096552.663961  385255388.6
# 1998          16.1297343275958      306478458500  ...  130759646.726695  407171308.9
# ...

# %%
sample = df.set_index(['Country name','Indicator']).stack().reset_index(level=2,drop=True).reset_index(name='Value')
sample
# Out:
#        Country name                             Indicator             Value
# 0         Argentina              Gross savings (% of GDP)  16.0433766574382
# 1         Argentina              Gross savings (% of GDP)  13.5618560304189
# 2         Argentina              Gross savings (% of GDP)  13.6516281676646
# 3         Argentina              Gross savings (% of GDP)  16.2505279122602
# 4         Argentina              Gross savings (% of GDP)  15.6483624533872
# ...             ...                                   ...               ...
# 234775     Zimbabwe  Use of IMF credit (DOD, current US$)                 0
# 234776     Zimbabwe  Use of IMF credit (DOD, current US$)                 0
# 234777     Zimbabwe  Use of IMF credit (DOD, current US$)                 0
# 234778     Zimbabwe  Use of IMF credit (DOD, current US$)                 0
# 234779     Zimbabwe  Use of IMF credit (DOD, current US$)                 0
#
# [234780 rows x 3 columns]

# %%
sample[sample['Country name'] == 'Argentina']
# Out:
#      Country name                             Indicator             Value
# 0       Argentina              Gross savings (% of GDP)  16.0433766574382
# 1       Argentina              Gross savings (% of GDP)  13.5618560304189
# 2       Argentina              Gross savings (% of GDP)  13.6516281676646
# 3       Argentina              Gross savings (% of GDP)  16.2505279122602
# 4       Argentina              Gross savings (% of GDP)  15.6483624533872
# ...           ...                                   ...               ...
# 1113    Argentina  Use of IMF credit (DOD, current US$)                 0
# 1114    Argentina  Use of IMF credit (DOD, current US$)                 0
# 1115    Argentina  Use of IMF credit (DOD, current US$)                 0
# 1116    Argentina  Use of IMF credit (DOD, current US$)                 0
# 1117    Argentina  Use of IMF credit (DOD, current US$)                 0
#
# [1118 rows x 3 columns]

# %%
sample['Indicator'].count()
# Out:
# 234780

# %%
sample['Indicator'].unique()
# Out:
# array(['Gross savings (% of GDP)',
#        'Gross national expenditure (current US$)', 'GDP (current US$)',
#        'GDP per capita (current US$)',
#        'Stocks traded, total value (current US$)',
#        'Adjusted net national income per capita (current US$)',
#        'Changes in inventories (current US$)',
#        'Current account balance (BoP, current US$)',
#        'Exports of goods and services (current US$)',
#        'External balance on goods and services (current US$)',
#        'Foreign direct investment, net outflows (BoP, current US$)',
#        'Imports of goods and services (current US$)',
#        'Industry (including construction), value added (current US$)',
#        'International tourism, receipts (current US$)',
#        'Market capitalization of listed domestic companies (current US$)',
#        'Personal remittances, received (current US$)',
#        'Personal remittances, paid (current US$)',
# ...

# %%
sample['Indicator'][:44]
# Out:
# 0                     Gross savings (% of GDP)
# 1                     Gross savings (% of GDP)
# 2                     Gross savings (% of GDP)
# 3                     Gross savings (% of GDP)
# 4                     Gross savings (% of GDP)
# 5                     Gross savings (% of GDP)
# 6                     Gross savings (% of GDP)
# 7                     Gross savings (% of GDP)
# 8                     Gross savings (% of GDP)
# 9                     Gross savings (% of GDP)
# 10                    Gross savings (% of GDP)
# 11                    Gross savings (% of GDP)
# 12                    Gross savings (% of GDP)
# 13                    Gross savings (% of GDP)
# 14                    Gross savings (% of GDP)
# 15                    Gross savings (% of GDP)
# 16                    Gross savings (% of GDP)
# 17                    Gross savings (% of GDP)
# 18                    Gross savings (% of GDP)
# 19                    Gross savings (% of GDP)
# ...

# %%
years = np.arange(1990,2021)
years2 = ["1990 target","2000 target","2008 target","2009 target","2010 target","2011 target","2012 target",
                "2013 target","2014 target","2015 target","2016 target","2017 target"]
years = years.tolist() + years2

# %%
total_years = len(years) * sample['Indicator'].count()
total_years
# Out:
# 10095540

# %%
sample['Year'] = np.divmod(np.arange(len(sample)),31)[0]+1990
sample['Year']
# Out:
# 0         1990
# 1         1990
# 2         1990
# 3         1990
# 4         1990
#           ...
# 234775    9563
# 234776    9563
# 234777    9563
# 234778    9563
# 234779    9563
# Name: Year, Length: 234780, dtype: int64

# %%
sample.head()
# Out:
#   Country name                 Indicator             Value  Year
# 0    Argentina  Gross savings (% of GDP)  16.0433766574382  1990
# 1    Argentina  Gross savings (% of GDP)  13.5618560304189  1990
# 2    Argentina  Gross savings (% of GDP)  13.6516281676646  1990
# 3    Argentina  Gross savings (% of GDP)  16.2505279122602  1990
# 4    Argentina  Gross savings (% of GDP)  15.6483624533872  1990

# %%
sample
# Out:
#        Country name  ...  Year
# 0         Argentina  ...  1990
# 1         Argentina  ...  1990
# 2         Argentina  ...  1990
# 3         Argentina  ...  1990
# 4         Argentina  ...  1990
# ...             ...  ...   ...
# 234775     Zimbabwe  ...  9563
# 234776     Zimbabwe  ...  9563
# 234777     Zimbabwe  ...  9563
# 234778     Zimbabwe  ...  9563
# 234779     Zimbabwe  ...  9563
#
# [234780 rows x 4 columns]

# %%
list_of_years = []

for x in np.arange(32):
  for x in years:
    list_of_years.append(x)

# %%
len(list_of_years)
# Out:
# 1376

# %%
new_list = []

for x in years:
  new_list.append(x)

# %%
new_list.append(years)

# %%
len(new_list)
# Out:
# 44

# %%
years_list = np.repeat(years, 7574)

# %%
len(years_list)
# Out:
# 325682

# %%
sample['Year'] = years_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-1f049fba12c0> in <module>()
# ----> 1 sample['Year'] = years_list
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# ...

# %%
sample.head()
# Out:
#   Country name                 Indicator             Value  Year
# 0    Argentina  Gross savings (% of GDP)  16.0433766574382  1990
# 1    Argentina  Gross savings (% of GDP)  13.5618560304189  1990
# 2    Argentina  Gross savings (% of GDP)  13.6516281676646  1990
# 3    Argentina  Gross savings (% of GDP)  16.2505279122602  1990
# 4    Argentina  Gross savings (% of GDP)  15.6483624533872  1990

# %%
sample.Year.unique()
# Out:
# array([1990, 1991, 1992, ..., 9561, 9562, 9563])

# %%
for x in years:
  np.repeat(x, 10)
  print(x)

# %%
years = years.tolist()

# %%
n = 5460
years_list = years * n

# %%
sample['Year'] = years_list

# %%
sample.head()
# Out:
#   Country name                 Indicator             Value  Year
# 0    Argentina  Gross savings (% of GDP)  16.0433766574382  1990
# 1    Argentina  Gross savings (% of GDP)  13.5618560304189  1991
# 2    Argentina  Gross savings (% of GDP)  13.6516281676646  1992
# 3    Argentina  Gross savings (% of GDP)  16.2505279122602  1993
# 4    Argentina  Gross savings (% of GDP)  15.6483624533872  1994

# %%
sample['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        '1990 target', '2000 target', '2008 target', '2009 target',
#        '2010 target', '2011 target', '2012 target', '2013 target',
#        '2014 target', '2015 target', '2016 target', '2017 target'],
#       dtype=object)

# %%
df_prueba = sample.copy()

# %%
df_prueba

# %%
df_prueba = df_prueba[['Country name','Year','Value','Indicator']]

# %%
Country_and_Years = df_prueba[['Country name','Year']]
Country_and_Years

# %%
# df_prueba.drop(['Country name','Year'], axis=1, inplace=True)

# %%
df_prueba

# %%
df_prueba.info()

# %%
df_prueba[df_prueba['Value'] == '..']

# %%
df_prueba['Value'] = df_prueba['Value'].replace('..',0)

# %%
df_prueba['Value'] = df_prueba['Value'].astype(int)

# %%
df_prueba

# %%
pd.crosstab(df_prueba['Country name'],df_prueba.Indicator, values=df_prueba.Value,aggfunc=sum)

# %%
df_prueba

# %%
df_prueba = df_prueba[['Country name','Year','Indicator','Value']]

# %%
df_prueba

# %%
df_final = df_prueba.pivot_table(values='Value',index=['Country name','Year'], columns='Indicator').reset_index()

# %%
df_final.head()

# %%
df_final['Year'].unique()

# %%
df_final.to_csv('ProyectoFinal.csv', index=False)

# %%
df_final.iloc[0:50]

# %%
df_final.to_csv('dfcondummies2.csv',index=False)

# %%
metrics = pd.read_csv('/content/drive/MyDrive/IronHack/Data Analysis/Bootcamp/Proyecto Final/ProyectoFinal.csv')

# %%
metrics

# %%
df_final2 = pd.concat([metrics, dummies], sort=False)
df_final2

# %%
df_final2.to_csv('dfcondummies.csv', index=False)

# %%
dummies

# %%
years

# %%
dummies.transpose()

# %%
dummies.set_index('Country name')

# %%
df1.drop(['Series Name','Series Code','Country Code'], axis=1, inplace=True)

# %%
dum_sample = df1.set_index(['Country Name']).stack().reset_index(level=1,drop=True).reset_index(name='Value')
dum_sample

# %%
dum_sample[dum_sample['Country Name'] == 'Argentina']

# %%
dum_years = ['1990',
 '2000',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017']

n2 = 214

dum_sample['Year'] = dum_years * n2

# %%
dum_sample.rename(columns={'Country Name':'Country name'},inplace=True)
dum_sample

# %%
dum_sample['Year'] = dum_sample['Year'].astype(int)

# %%
dum_sample.info()

# %%
metrics.info()

# %%
df_test4 = pd.merge(metrics, dum_sample, on=['Country name','Year'])

# %%
df_test4['Year'].unique()

# %%
df_test4

# %%
df_test4.to_csv('datasetbueno.csv', index=False)

# %%
dummies = pd.read_csv('/content/drive/MyDrive/IronHack/Data Analysis/Bootcamp/Proyecto Final/Backups/dfcondummies.csv')

# %%
dummies.head()

# %%
sample.head()
